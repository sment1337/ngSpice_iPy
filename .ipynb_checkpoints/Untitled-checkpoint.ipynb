# %%
# %matplotlib notebook
from ngInterfacer import *
import matplotlib.pyplot as plt

# %%
sim = data()
sim.extract()

# %%
plt.plot(sim.x, sim.y)

# %%
from ipywidgets import *
import numpy as np


x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update, w=widgets.IntSlider(min=-10, max=30, step=1, value=10));
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=10, description='w', max=30, min=-10), Output()), _dom_classes=('widget-…
